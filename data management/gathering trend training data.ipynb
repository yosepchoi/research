# %%
import sys
sys.path.append('..')
from modules.db_manager import gathering_trend, open_file

# %% [markdown]
# ### 0. Parameters

# %%
raw_file = open_file('h5py', 'raw data/daily_futures.h5', mode='r')

# %%
window = 20
filepath = 'training set/20day-trend-training_set.h5'

# %% [markdown]
# ### 1. Gathering Data

# %%
gathering_trend(filepath, raw_file, window)
# Out:
# CME_S
# range:  6.22727272727
# 하락(0), 기타(1), 상승(2): q

# %% [markdown]
# ### 2. Verification

# %%
from collections import Counter

# %%
file = open_file('h5py', filepath, mode='r')

# %%
print(file['X'].shape)
print(file['Y'].shape)
# Out:
# (1, 20, 4)
# (1,)

# %%
Y = file['Y']
Counter(Y)
# Out:
# Counter({1: 1})
